# %%
import tensorflow as tf
from donkey import Donkey
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
image_batch, length_batch, digits_batch, letters_batch = Donkey.build_batch('data/train.tfrecords', num_examples=100, batch_size=36, shuffled=False)

# %%
sess = tf.InteractiveSession()
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(coord=coord)

# %%
image_batch_val, length_batch_val, digits_batch_val, letters_batch_val = sess.run([image_batch, length_batch, digits_batch, letters_batch])
image_batch_val = (image_batch_val / 2.0) + 0.5

# %%
fig, axes = plt.subplots(6, 6, figsize=(80, 20))
for i, ax in enumerate(axes.flat): 
    title = 'length: %d\ndigits: %d,%d,%d,%d,%d,%d,%d,%d,%d' % (length_batch_val[i],
                                                    digits_batch_val[i][0],
                                                    letters_batch_val[i][0],
                                                    letters_batch_val[i][1],
                                                    letters_batch_val[i][2],
                                                    digits_batch_val[i][1],
                                                    digits_batch_val[i][2],
                                                    digits_batch_val[i][3],
                                                    letters_batch_val[i][3],
                                                    letters_batch_val[i][4])
    ax.imshow(image_batch_val[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
sess = tf.InteractiveSession()
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(coord=coord)
